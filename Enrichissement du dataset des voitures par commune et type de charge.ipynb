# %% [markdown]
# ### Datasets utilisés
# - 1. Voitures particulières immatriculées par commune et par type de charge: https://www.data.gouv.fr/fr/datasets/voitures-particulieres-immatriculees-par-commune-et-par-type-de-recharge/
# - 2. API découpage administratif des communes: https://geo.api.gouv.fr/decoupage-administratif/communes
# - 3. Départements de France: https://www.data.gouv.fr/fr/datasets/departements-de-france/

# %% [markdown]
# ## Objectif du notebook:
# Récuprer les infos sur les communes: notamment département / région / population pour les merger avec les données des immatriculations par commune et par type de charge.

# %%
# Import des librairies
import requests
import json
import pandas as pd

# %%
# Importer les données des immatriculations
immatriculations = pd.read_csv('new_data/voitures-rechargeables-par-commune.csv', sep=';', dtype={'codgeo': 'str'})
immatriculations
# Out:
#        codgeo    libgeo       epci                       libepci date_arrete  \
# 0       35081    CLAYES  243500139              Rennes Métropole  2022-06-30
# 1       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2020-12-31
# 2       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-03-31
# 3       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-12-31
# 4       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2022-03-31
# ...       ...       ...        ...                           ...         ...
# 316607  23100  JARNAGES  200067544          CC Creuse Confluence  2021-06-30
# 316608  23100  JARNAGES  200067544          CC Creuse Confluence  2022-03-31
# 316609  23100  JARNAGES  200067544          CC Creuse Confluence  2022-06-30
# 316610  23101  JOUILLAT  200034825            CA du Grand Guéret  2020-12-31
# 316611  23101  JOUILLAT  200034825            CA du Grand Guéret  2022-03-31
#
#         nb_vp_rechargeables_el  nb_vp_rechargeables_gaz  nb_vp
# 0                            9                        0    821
# 1                            2                        0   1533
# 2                            2                        0   1534
# 3                            4                        0   1545
# 4                            6                        0   1543
# ...                        ...                      ...    ...
# 316607                       3                        0    527
# 316608                       3                        0    534
# 316609                       5                        0    533
# 316610                       0                        0    471
# 316611                       1                        0    462
#
# [316612 rows x 8 columns]

# %%
# Récupérer l'ensemble des communes de France

url = f"https://geo.api.gouv.fr/communes"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

communes_list = json.loads(response.text)
communes_df = pd.DataFrame(communes_list)

# %%
communes_df
# Out:
#                            nom   code codeDepartement      siren   codeEpci  \
# 0      L'Abergement-Clémenciat  01001              01  210100012  200069193
# 1        L'Abergement-de-Varey  01002              01  210100020  240100883
# 2            Ambérieu-en-Bugey  01004              01  210100046  240100883
# 3          Ambérieux-en-Dombes  01005              01  210100053  200042497
# 4                      Ambléon  01006              01  210100061  200040350
# ...                        ...    ...             ...        ...        ...
# 35044                    Touho  98830             988        NaN        NaN
# 35045                      Voh  98831             988        NaN        NaN
# 35046                     Yaté  98832             988        NaN        NaN
# 35047                  Kouaoua  98833             988        NaN        NaN
# 35048        Île de Clipperton  98901             989        NaN        NaN
#
#       codeRegion codesPostaux  population
# 0             84      [01400]       779.0
# 1             84      [01640]       256.0
# 2             84      [01500]     14134.0
# 3             84      [01330]      1751.0
# 4             84      [01300]       112.0
# ...          ...          ...         ...
# 35044        988      [98831]      2380.0
# 35045        988      [98833]      2856.0
# 35046        988      [98834]      1667.0
# 35047        988      [98818]      1304.0
# 35048        989      [98799]         NaN
#
# [35049 rows x 8 columns]

# %%
print("nombre de codes de communes uniques dans le dataset des immatriculations: ", immatriculations['codgeo'].nunique())
print("nombre de codes de communes uniques dans le dataset des communes: ", communes_df['code'].nunique())
# Out:
# nombre de codes de communes uniques dans le dataset des immatriculations:  35189
# nombre de codes de communes uniques dans le dataset des communes:  35049

# %% [markdown]
# #### Observation
# Il semble manquer environ 100 communes dans le dataset des communes...

# %% [markdown]
# ### Merger les 2 datasets: communes et immatriculations

# %%
# Merge les 2 datasets (immatriculations et communes) sur le code INSEE
immatriculations = immatriculations.merge(communes_df, left_on='codgeo', right_on='code', how='left')
immatriculations
# Out:
#        codgeo    libgeo       epci                       libepci date_arrete  \
# 0       35081    CLAYES  243500139              Rennes Métropole  2022-06-30
# 1       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2020-12-31
# 2       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-03-31
# 3       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-12-31
# 4       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2022-03-31
# ...       ...       ...        ...                           ...         ...
# 316607  23100  JARNAGES  200067544          CC Creuse Confluence  2021-06-30
# 316608  23100  JARNAGES  200067544          CC Creuse Confluence  2022-03-31
# 316609  23100  JARNAGES  200067544          CC Creuse Confluence  2022-06-30
# 316610  23101  JOUILLAT  200034825            CA du Grand Guéret  2020-12-31
# 316611  23101  JOUILLAT  200034825            CA du Grand Guéret  2022-03-31
#
#         nb_vp_rechargeables_el  nb_vp_rechargeables_gaz  nb_vp       nom  \
# 0                            9                        0    821    Clayes
# 1                            2                        0   1533   Coësmes
# 2                            2                        0   1534   Coësmes
# 3                            4                        0   1545   Coësmes
# 4                            6                        0   1543   Coësmes
# ...                        ...                      ...    ...       ...
# 316607                       3                        0    527  Jarnages
# 316608                       3                        0    534  Jarnages
# 316609                       5                        0    533  Jarnages
# 316610                       0                        0    471  Jouillat
# 316611                       1                        0    462  Jouillat
#
#          code codeDepartement      siren   codeEpci codeRegion codesPostaux  \
# 0       35081              35  213500812  243500139         53      [35590]
# 1       35082              35  213500820  243500634         53      [35134]
# 2       35082              35  213500820  243500634         53      [35134]
# 3       35082              35  213500820  243500634         53      [35134]
# 4       35082              35  213500820  243500634         53      [35134]
# ...       ...             ...        ...        ...        ...          ...
# 316607  23100              23  212310007  200067544         75      [23140]
# 316608  23100              23  212310007  200067544         75      [23140]
# 316609  23100              23  212310007  200067544         75      [23140]
# 316610  23101              23  212310106  200034825         75      [23220]
# 316611  23101              23  212310106  200034825         75      [23220]
#
#         population
# 0            908.0
# 1           1465.0
# 2           1465.0
# 3           1465.0
# 4           1465.0
# ...            ...
# 316607       439.0
# 316608       439.0
# 316609       439.0
# 316610       387.0
# 316611       387.0
#
# [316612 rows x 16 columns]

# %%
# Supprimer les colonnes redondantes
immatriculations = immatriculations.drop(columns=['nom', 'code', 'codeEpci'])
immatriculations
# Out:
#        codgeo    libgeo       epci                       libepci date_arrete  \
# 0       35081    CLAYES  243500139              Rennes Métropole  2022-06-30
# 1       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2020-12-31
# 2       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-03-31
# 3       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-12-31
# 4       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2022-03-31
# ...       ...       ...        ...                           ...         ...
# 316607  23100  JARNAGES  200067544          CC Creuse Confluence  2021-06-30
# 316608  23100  JARNAGES  200067544          CC Creuse Confluence  2022-03-31
# 316609  23100  JARNAGES  200067544          CC Creuse Confluence  2022-06-30
# 316610  23101  JOUILLAT  200034825            CA du Grand Guéret  2020-12-31
# 316611  23101  JOUILLAT  200034825            CA du Grand Guéret  2022-03-31
#
#         nb_vp_rechargeables_el  nb_vp_rechargeables_gaz  nb_vp  \
# 0                            9                        0    821
# 1                            2                        0   1533
# 2                            2                        0   1534
# 3                            4                        0   1545
# 4                            6                        0   1543
# ...                        ...                      ...    ...
# 316607                       3                        0    527
# 316608                       3                        0    534
# 316609                       5                        0    533
# 316610                       0                        0    471
# 316611                       1                        0    462
#
#        codeDepartement      siren codeRegion codesPostaux  population
# 0                   35  213500812         53      [35590]       908.0
# 1                   35  213500820         53      [35134]      1465.0
# 2                   35  213500820         53      [35134]      1465.0
# 3                   35  213500820         53      [35134]      1465.0
# 4                   35  213500820         53      [35134]      1465.0
# ...                ...        ...        ...          ...         ...
# 316607              23  212310007         75      [23140]       439.0
# 316608              23  212310007         75      [23140]       439.0
# 316609              23  212310007         75      [23140]       439.0
# 316610              23  212310106         75      [23220]       387.0
# 316611              23  212310106         75      [23220]       387.0
#
# [316612 rows x 13 columns]

# %%
# Merger avec les noms des départements et régions
departements = (pd.read_csv('new_data/departements-france.csv')
    .rename(columns={'code_departement': 'codeDepartement'}).drop(columns=['code_region']))
immatriculations = immatriculations.merge(departements, on='codeDepartement', how='left')
immatriculations
# Out:
#        codgeo    libgeo       epci                       libepci date_arrete  \
# 0       35081    CLAYES  243500139              Rennes Métropole  2022-06-30
# 1       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2020-12-31
# 2       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-03-31
# 3       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-12-31
# 4       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2022-03-31
# ...       ...       ...        ...                           ...         ...
# 316607  23100  JARNAGES  200067544          CC Creuse Confluence  2021-06-30
# 316608  23100  JARNAGES  200067544          CC Creuse Confluence  2022-03-31
# 316609  23100  JARNAGES  200067544          CC Creuse Confluence  2022-06-30
# 316610  23101  JOUILLAT  200034825            CA du Grand Guéret  2020-12-31
# 316611  23101  JOUILLAT  200034825            CA du Grand Guéret  2022-03-31
#
#         nb_vp_rechargeables_el  nb_vp_rechargeables_gaz  nb_vp  \
# 0                            9                        0    821
# 1                            2                        0   1533
# 2                            2                        0   1534
# 3                            4                        0   1545
# 4                            6                        0   1543
# ...                        ...                      ...    ...
# 316607                       3                        0    527
# 316608                       3                        0    534
# 316609                       5                        0    533
# 316610                       0                        0    471
# 316611                       1                        0    462
#
#        codeDepartement      siren codeRegion codesPostaux  population  \
# 0                   35  213500812         53      [35590]       908.0
# 1                   35  213500820         53      [35134]      1465.0
# 2                   35  213500820         53      [35134]      1465.0
# 3                   35  213500820         53      [35134]      1465.0
# 4                   35  213500820         53      [35134]      1465.0
# ...                ...        ...        ...          ...         ...
# 316607              23  212310007         75      [23140]       439.0
# 316608              23  212310007         75      [23140]       439.0
# 316609              23  212310007         75      [23140]       439.0
# 316610              23  212310106         75      [23220]       387.0
# 316611              23  212310106         75      [23220]       387.0
#
#         nom_departement          nom_region
# 0       Ille-et-Vilaine            Bretagne
# 1       Ille-et-Vilaine            Bretagne
# 2       Ille-et-Vilaine            Bretagne
# 3       Ille-et-Vilaine            Bretagne
# 4       Ille-et-Vilaine            Bretagne
# ...                 ...                 ...
# 316607           Creuse  Nouvelle-Aquitaine
# 316608           Creuse  Nouvelle-Aquitaine
# 316609           Creuse  Nouvelle-Aquitaine
# 316610           Creuse  Nouvelle-Aquitaine
# 316611           Creuse  Nouvelle-Aquitaine
#
# [316612 rows x 15 columns]

# %%
# Ajustements sur la structure du DataFrame
column_order = [
     'codgeo',
     'libgeo',
     'epci',
     'libepci',
     'date_arrete',
     'nb_vp_rechargeables_el',
     'nb_vp_rechargeables_gaz',
     'nb_vp',
     'code_departement',
     'nom_departement',
     'code_region',
     'nom_region',
     'codes_postaux',
     'population',
     'siren'
]
immatriculations = immatriculations.rename(columns={'codeDepartement': 'code_departement',
                                 'codeRegion': 'code_region',
                                 'codesPostaux': 'codes_postaux'})[column_order]
immatriculations
# Out:
#        codgeo    libgeo       epci                       libepci date_arrete  \
# 0       35081    CLAYES  243500139              Rennes Métropole  2022-06-30
# 1       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2020-12-31
# 2       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-03-31
# 3       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2021-12-31
# 4       35082   COËSMES  243500634  CC Roche aux Fées Communauté  2022-03-31
# ...       ...       ...        ...                           ...         ...
# 316607  23100  JARNAGES  200067544          CC Creuse Confluence  2021-06-30
# 316608  23100  JARNAGES  200067544          CC Creuse Confluence  2022-03-31
# 316609  23100  JARNAGES  200067544          CC Creuse Confluence  2022-06-30
# 316610  23101  JOUILLAT  200034825            CA du Grand Guéret  2020-12-31
# 316611  23101  JOUILLAT  200034825            CA du Grand Guéret  2022-03-31
#
#         nb_vp_rechargeables_el  nb_vp_rechargeables_gaz  nb_vp  \
# 0                            9                        0    821
# 1                            2                        0   1533
# 2                            2                        0   1534
# 3                            4                        0   1545
# 4                            6                        0   1543
# ...                        ...                      ...    ...
# 316607                       3                        0    527
# 316608                       3                        0    534
# 316609                       5                        0    533
# 316610                       0                        0    471
# 316611                       1                        0    462
#
#        code_departement  nom_departement code_region          nom_region  \
# 0                    35  Ille-et-Vilaine          53            Bretagne
# 1                    35  Ille-et-Vilaine          53            Bretagne
# 2                    35  Ille-et-Vilaine          53            Bretagne
# 3                    35  Ille-et-Vilaine          53            Bretagne
# 4                    35  Ille-et-Vilaine          53            Bretagne
# ...                 ...              ...         ...                 ...
# 316607               23           Creuse          75  Nouvelle-Aquitaine
# 316608               23           Creuse          75  Nouvelle-Aquitaine
# 316609               23           Creuse          75  Nouvelle-Aquitaine
# 316610               23           Creuse          75  Nouvelle-Aquitaine
# 316611               23           Creuse          75  Nouvelle-Aquitaine
#
#        codes_postaux  population      siren
# 0            [35590]       908.0  213500812
# 1            [35134]      1465.0  213500820
# 2            [35134]      1465.0  213500820
# 3            [35134]      1465.0  213500820
# 4            [35134]      1465.0  213500820
# ...              ...         ...        ...
# 316607       [23140]       439.0  212310007
# 316608       [23140]       439.0  212310007
# 316609       [23140]       439.0  212310007
# 316610       [23220]       387.0  212310106
# 316611       [23220]       387.0  212310106
#
# [316612 rows x 15 columns]

# %%
# Exporter le résultat
immatriculations.to_csv('new_data/voitures-rechargeables-par-commune-enrichies.csv', index=False)
